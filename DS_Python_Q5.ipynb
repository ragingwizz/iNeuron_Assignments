# %% [markdown]
# <a href="https://colab.research.google.com/github/ragingwizz/iNeuron_Assignments/blob/main/DS_Python_Q5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import csv


# Step 1: Download the data from the provided API link
url = "http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes"
response = requests.get(url)
data = response.json()

# Step 2: Extract the desired data attributes with proper formatting
show_id = data["id"]
show_url = data["url"]
show_name = data["name"]

episodes = data["_embedded"]["episodes"]
formatted_episodes = []

for episode in episodes:
    episode_id = episode["id"]
    episode_season = episode["season"]
    episode_number = episode["number"]
    episode_type = episode["type"]
    episode_airdate = episode["airdate"]
    episode_airtime = episode["airtime"]
    episode_runtime = episode["runtime"]
    episode_average_rating = episode["rating"]["average"]
    episode_summary = episode["summary"].strip("<p>").strip("</p>")
    episode_image_medium = episode["image"]["medium"]
    episode_image_original = episode["image"]["original"]

    formatted_episodes.append({
        "id": episode_id,
        "url": show_url,
        "name": show_name,
        "season": episode_season,
        "number": episode_number,
        "type": episode_type,
        "airdate": episode_airdate,
        "airtime": episode_airtime,
        "runtime": episode_runtime,
        "average rating": episode_average_rating,
        "summary": episode_summary,
        "medium image link": episode_image_medium,
        "original image link": episode_image_original
    })

# Step 3: Print the extracted data attributes
# for episode in formatted_episodes:
#     print("Episode ID:", episode["id"])
#     print("Show URL:", episode["url"])
#     print("Show Name:", episode["name"])
#     print("Season:", episode["season"])
#     print("Episode Number:", episode["number"])
#     print("Type:", episode["type"])
#     print("Airdate:", episode["airdate"])
#     print("Airtime:", episode["airtime"])
#     print("Runtime:", episode["runtime"])
#     print("Average Rating:", episode["average rating"])
#     print("Summary:", episode["summary"])
#     print("Medium Image Link:", episode["medium image link"])
#     print("Original Image Link:", episode["original image link"])
#     print("------------------------------------")

# If you want to save the extracted data as a JSON file, you can uncomment the following lines:
output_file = "westworld_episodes.csv"
# with open(output_file, "w") as file:
#     json.dump(formatted_episodes, file, indent=4)


# Step 4: Write the structured data to the CSV file
with open(output_file, "w", newline="") as file:
    writer = csv.DictWriter(file, fieldnames=formatted_episodes[0].keys())

    # Write the header
    writer.writeheader()

    # Write the data rows
    writer.writerows(formatted_episodes)

print("Data has been successfully converted to CSV format.")
print("Output file:", output_file)
# Out:
# Data has been successfully converted to CSV format.
# Output file: westworld_episodes.csv

# %%
import pandas as pd
df = pd.read_csv("/content/westworld_episodes.csv")
df
# Out:
#          id                                          url       name  season  \
# 0    869671  https://www.tvmaze.com/shows/1371/westworld  Westworld       1
# 1    911201  https://www.tvmaze.com/shows/1371/westworld  Westworld       1
# 2    911204  https://www.tvmaze.com/shows/1371/westworld  Westworld       1
# 3    911205  https://www.tvmaze.com/shows/1371/westworld  Westworld       1
# 4    927174  https://www.tvmaze.com/shows/1371/westworld  Westworld       1
# 5    932057  https://www.tvmaze.com/shows/1371/westworld  Westworld       1
# 6    938404  https://www.tvmaze.com/shows/1371/westworld  Westworld       1
# 7    943065  https://www.tvmaze.com/shows/1371/westworld  Westworld       1
# 8    943066  https://www.tvmaze.com/shows/1371/westworld  Westworld       1
# 9    943067  https://www.tvmaze.com/shows/1371/westworld  Westworld       1
# 10  1214222  https://www.tvmaze.com/shows/1371/westworld  Westworld       2
# ...
